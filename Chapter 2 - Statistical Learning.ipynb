# %%
# Here's all of our data sets for these labs 

# !dir data
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is 3419-795B
#
#  Directory of C:\Users\206493752\Dropbox\Asus\Jupyter\Intro to Statistical Learning Labs\data
#
# 02/08/2019  11:04 AM    <DIR>          .
# 02/08/2019  11:04 AM    <DIR>          ..
# 02/08/2019  11:03 AM             4,213 Advertising.csv
# 02/08/2019  11:03 AM            19,397 auto.csv
# 02/08/2019  11:03 AM            41,070 boston.csv
# 02/08/2019  11:03 AM         1,018,824 caravan.csv
# 02/08/2019  11:03 AM            17,029 carseats.csv
# 02/08/2019  11:03 AM            75,701 college.csv
# 02/08/2019  11:03 AM            22,323 Credit.csv
# 02/08/2019  11:03 AM           414,711 default.csv
# 02/08/2019  11:03 AM            28,010 hitters.csv
# 02/08/2019  11:03 AM           619,639 khan_xtest.csv
# 02/08/2019  11:03 AM         1,512,989 khan_xtrain.csv
# 02/08/2019  11:03 AM               159 khan_ytest.csv
# 02/08/2019  11:03 AM               503 khan_ytrain.csv
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# # Conceptual Problems

# %% [markdown]
# ## Question 1
# 1. For each of parts (a) through (d), indicate whether we would generally expect the performance of a flexible statistical learning method to be better or worse than an inflexible method. Justify your answer.
#
#   1. The sample size n is extremely large, and the number of predictors p is small.
#   2. The number of predictors p is extremely large, and the number of observations n is small.
#   3. The relationship between the predictors and response is highly non-linear.
#   4. The variance of the error terms, i.e. σ2 = Var(), is extremely high.

# %% [markdown]
# A) Flexible model. It would fit the data closer. A large number of observations prevents the model from following noise, and the small number of predictors would also help the model.
#
# B) Inflexible model. A low number of observations can introduce lots of variance, so a flexible model would overfit to the small number of observations.
#
# C) Flexible model. Flexible models are better for complex relationships.
#
# D) Inflexible model, since flexible models can be easily affected by noise.

# %% [markdown]
# ## Question 2
#
# 2. Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.
#   1. We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.
#   2. We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.
#   3. We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.

# %% [markdown]
# A) Regression problem, inference. $n = 500, p = 3$
#
# B) Classification problem, prediction. $n = 20, p = 13$
#
# C) Regression problem, prediction. $n = 52, p = 3$

# %% [markdown]
# ## Question 3
#
# 1. We now revisit the bias-variance decomposition.
#   1. Provide a sketch of typical (squared) bias, variance, training error, test error, and Bayes (or irreducible) error cruves on a single plot, as we go from less flexible statistical learning methods towards more flexible approaches. The x-axis should represent the amount of flexibility in the method, and the y-axis should represent the values for each curve. There should be five curves
#   2. Explain why each of the five curves has the shape displayed in a

# %%
flexibility = [0, 1, 2, 3, 4, 5]
bias = np.array([6, 4, 2, 1, .5, .1])
variance = [.1, .5, 1, 2, 4, 6]
training_error = bias * 1.1
test_error = [7, 5, 2, 2, 5, 7]
irreducible_error = [1.5, 1.5, 1.5, 1.5, 1.5, 1.5]

# %%
plt.plot(flexibility, bias,
         flexibility, variance,
         flexibility, training_error,
         flexibility, test_error,
         flexibility, irreducible_error)
plt.xlabel('Flexibility')
plt.legend(labels=('Bias', 'Variance', 'Training Error', 'Test Error', 'Irreducible Error'))
plt.show()

# %% [markdown]
# Bias decreases with more flexible models, as an inflexible model is unlikely to match the real-life situation
#
# Variance increases with more flexible models, since noise can affect the model more
#
# Training error decreases with more flexible models, and can even decrease to 0 if we overfit to all of the error
#
# Test error is optimized somewhere in the middle - too inflexible and the model will be too far from the truth of the data set and too flexible can cause over-fitting
#
# The irreducible error is constant noise inherent in the data. When the training error is less than the irreducible error, there has been overfitting. The test error is bounded below by the irreducible error.

# %% [markdown]
# ## Question 4
#
# 1. You will now think of some real-life applications for statistical learning.
#   1. Describe three real-life applications in which classification might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
#   2. Describe three real-life applications in which regression might be useful. Describe the response, as well as the predictors. Is the goal of each application inference or prediction? Explain your answer.
#   3. Describe three real-life applications in which cluster analysis might be useful.

# %% [markdown]
# A)
# * One example is classifying text documents into topics. The predictors are the tf-idf values of the words, potentially bigrams as well as unigrams, and the response would be a discrete topic, like 'Health & Fitness', or 'Electronics', or perhaps 'Positive' and 'Negative' is you're doing sentiment analysis. The goal is prediction.
# * Another example is using classification to determine whether a tumor is cancerous or not. The predictors could be image data from MRI scans. The goal is both prediction and inference.
# * Another example is classifying a voice as a child's voice or an adult voice. The predictors would be audio signal data, such as frequency domain information. The goal is prediction.
#
# B)
# * You can use regression to estimate a person's salary, using education, industry, race, and gender as predictors. The goal is inference and prediction
# * You can also use it to estimate how a movie will perform at the box office, using predictors like budget, movie rating, critic review score, and the cast. The goal is prediction and inference
# * You can also use regression to estimate stock prices over time, using the % change over the last day, % change over the last 2 days, the industry, etc. The goal is prediction
#
# C)
# * You can use clustering for audience segmentation of a product to understand the types of customer archetypes present
# * You can also cluster images, separating them by visual similarity.
# * You can also cluster books based off of its excerpts to categorize it into discrete genres

# %% [markdown]
# ## Question 5
#
# What are the advantages and disadvantages of a very flexible (versus a less flexible) approach for regression or classification? Under what circumstances might a more flexible approach be preferred to a less flexible approach? When might a less flexible approach be preferred?

# %% [markdown]
# A flexible method is preferred when the relationship appears very complex and non-linear, as it has a lower bias. The disadvantages are that it can follow the noise too closely and overfit the data, so it's not good in situations where you have relatively few samples. A flexible method is also harder to interpret the results, so it's better when you're interested in prediction and not inference.
#
# A less flexible method is preferred when you want to be able to easily interpret the results for inferrence. It will have a higher bias, but less variance so it's more robust to noise. Less flexible is preferred when you have a smaller data set and a large number of features relative to the number of observations.

# %% [markdown]
# ## Question 6
#
# Describe the differences between a parametric and a non-parametric statistical learning approach. What are the advantages of a parametric approach to regression or classification as opposed to a non-parametric approach? What are the disadvantages?

# %% [markdown]
# The parametric approach is less flexible - it assumes a form for $f$ and locks you into a model with a certain structure. With the parametric approach, you estimate the parameters for the assumed form of $f$. Advantages are its simplicity, direct inference of the predictors, and less computational time to optimize the parameters for the model. The disadvantage is the lack of flexibility. If you choose a poor parametric model, it may not match real-life very well and cause a significant error from bias
#
# The non-parametric approach does not assume a form for $f$ so it's highly flexible. However, it requires a very large number of observations in order to accurately estimate f, and it's possible to overfit to the observations.

# %% [markdown]
# ## Question 7
#
# The table below provides a training data set containing six observations, three predictors, and one qualitative response variable.
#
# ![image.png](attachment:image.png)
#
# Suppose we wish to use this data set to make a prediction for $Y$ when $X_1 = X_2 = X_3 = 0$ using K-nearest neighbors
#
# 1.
#   1. Compute the Euclidean distance between each observation and the test point, $X_1 = X_2 = X_3 = 0$
#   2. What is our prediction with K = 1? Why?
#   3. What is our prediction with K = 3? Why?
#   4. If the Bayes decision boundary in this problem is highly non-linear, then would we expect the best value for K to be large or small? Why?

# %% [markdown]
# 1.
#   1.
#     * Observation 1: $ \sqrt{0^2 + 3^2 + 0^2} = 3 $
#     * Observation 2: $ \sqrt{2^2 + 0^2 + 0^2} = 2 $
#     * Observation 3: $ \sqrt{0^2 + 1^2 + 3^2} \approx 3.16 $
#     * Observation 4: $ \sqrt{0^2 + 1^2 + 2^2} \approx 2.24 $
#     * Observation 5: $ \sqrt{(-1)^2 + 0^2 + 1^2} \approx 1.41 $
#     * Observation 6: $ \sqrt{1^2 + 1^2 + 1^2} \approx 1.73 $
#   2. The nearest neighbor to point (0, 0, 0) is observation 5, which is **Green**.
#   3. The 3 nearest neighbors are observation 5, 6, and 2. The majority of these observations are **Red**
#   4. It would be better to have a smaller K, since a small K is flexible for a non-linear decision boundary and would allow more local changes to contribute to the prediction. Large K would try to fit a more linear boundary, because it takes more points into consideration.

# %% [markdown]
# # Applied Problems

# %% [markdown]
# ## Question 8
#
# We'll be using the $College$ data set. It contains a number of variables for 777 different colleges in the US
#
# * Private : Public/private indicator
# * Apps : Number of applications received
# * Accept : Number of applicants accepted
# * Enroll : Number of new students enrolled
# * Top10perc : New students from top 10 % of high school class
# * Top25perc : New students from top 25 % of high school class
# * F.Undergrad : Number of full-time undergraduates
# * P.Undergrad : Number of part-time undergraduates
# * Outstate : Out-of-state tuition
# * Room.Board : Room and board costs
# * Books : Estimated book costs
# * Personal : Estimated personal spending
# * PhD : Percent of faculty with Ph.D.’s
# * Terminal : Percent of faculty with terminal degree
# * S.F.Ratio : Student/faculty ratio
# * perc.alumni : Percent of alumni who donate
# * Expend : Instructional expenditure per student
# * Grad.Rate : Graduation rate

# %%
df_college = pd.read_csv('data/College.csv')
df_college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# ### Part C
#
# 1. Produce a numerical summary of the variables in the data set
# 2. Produce a scatterplot matrix of the first ten columns or variables of data.
# 3. Produce side-by-side boxplots of Outstate vs. Private
# 4. Create a new qualitative variable called Elite by binning the Top10perc variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school exceeds 50%. Use the summary function to see how many elite universities there are. Then produce side-by-side boxplots of Outstate vs. Elite
# 5. Use the histogram function to produce some histograms with differing number of bins for a few of the quantitative variables.
# 6. Continue exploring the data and provide a brief summary of what you discover

# %%
# Part 1

df_college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# Part 2

sns.pairplot(df_college.iloc[:,:10])
plt.show()

# %%
# Part 3

#sns.boxplot(x=df_college['Private'], y=df_college['Outstate'])
sns.boxplot('Private', 'Outstate', data=df_college)
plt.title('Out of State Tuition for Private vs. Public Schools')
plt.show()

# %%
# Part 4
df_college['Elite'] = pd.Categorical(np.where(df_college['Top10perc'] > 50, 'Yes', 'No'))
print(df_college['Elite'].value_counts())
sns.boxplot('Elite', 'Outstate', data=df_college)
plt.title('Out of State Tuition for Elite vs. Non-Elite Schools')
plt.show()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
# Part 5
fig, axes = plt.subplots(2, 2)

axes[0, 0].hist(df_college['S.F.Ratio'], bins = 5)
axes[0, 1].hist(df_college['S.F.Ratio'], bins = 10)
axes[1, 0].hist(df_college['S.F.Ratio'], bins = 20)
axes[1, 1].hist(df_college['S.F.Ratio'], bins = 30)
fig.suptitle('S.F.Ratio Histogram with Various Bins')
plt.show()

# %%
# Part 6

# Graduation rate is correlated with out of state tuition

sns.lmplot('Outstate', 'Grad.Rate', data=df_college)
plt.show()
# Out:
# C:\Users\206493752\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Graduation rate is negatively correlated with student-faculty ratio

sns.lmplot('S.F.Ratio', 'Grad.Rate', data=df_college)
plt.show()
# Out:
# C:\Users\206493752\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Graduation rate is higher for elite schools

sns.boxplot('Elite', 'Grad.Rate', data=df_college)
plt.title('Graduation Rate for Elite vs. Non-Elite Schools')
plt.show()

# %% [markdown]
# ## Question 9
#
# This exercise uses the `Auto` data set

# %%
df_auto = pd.read_csv('data/auto.csv')
df_auto.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0    70
# 1  15.0          8         350.0         165    3693          11.5    70
# 2  18.0          8         318.0         150    3436          11.0    70
# 3  16.0          8         304.0         150    3433          12.0    70
# 4  17.0          8         302.0         140    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df_auto.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration        year      origin
# count    392.000000  392.000000  392.000000
# mean      15.541327   75.979592    1.576531
# std        2.758864    3.683737    0.805518
# min        8.000000   70.000000    1.000000
# 25%       13.775000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %% [markdown]
# 1.
#     1. Which of the predictors are quantitative, and which are qualitative?
#     2. What is the range of each quantitative predictor?
#     3. What is the mean and standard deviation of each quantitative predictor?
#     4. Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset data that remains?
#     5. Using the full data set, investigate the predictors graphically. Create some plots highlighting the relationships among the predictors. Comment on your findings
#     6. Suppose we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg?

# %% [markdown]
# A)
#
# Quantitative: mpg, displacement, horsepower, weight, acceleration, cylinders
#
# Qualitative: year, origin, name (Though these are numeric, they have a small discrete set of possible values, so it can be treated as categorical)

# %% [markdown]
# B)
#
# * mpg: [9, 46]
# * cylinders: [3, 8]
# * displacement: [68, 455]
# * horsepower: [46, 230]
# * weight: [1613, 5140]
# * acceleration: [8, 24.8]
#
# C)
#
# * mpg
#   * mean: 23.5
#   * std: 7.8
# * cylinders
#   * mean: 5.5
#   * std: 1.7
# * displacement
#   * mean: 194.4
#   * std: 104.6
# * horsepower
#   * mean: 104.5
#   * std: 38.5
# * weight
#   * mean: 2977.6
#   * std: 849.4
# * acceleration
#   * 15.5
#   * std: 2.8

# %%
df_auto_subset = pd.concat([df_auto.iloc[:10], df_auto.iloc[85:]])
df_auto_subset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# 5    15.0          8         429.0         198    4341          10.0    70
# 6    14.0          8         454.0         220    4354           9.0    70
# 7    14.0          8         440.0         215    4312           8.5    70
# 8    14.0          8         455.0         225    4425          10.0    70
# 9    15.0          8         390.0         190    3850           8.5    70
# 85   14.0          8         304.0         150    3672          11.5    73
# ...

# %%
# D)

df_auto_subset.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  317.000000  317.000000    317.000000  317.000000   317.000000
# mean    24.374763    5.381703    187.880126  101.003155  2938.854890
# std      7.872565    1.658135    100.169973   36.003208   811.640668
# min     11.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     18.000000    4.000000    101.000000   75.000000  2215.000000
# 50%     23.900000    4.000000    146.000000   90.000000  2795.000000
# 75%     30.500000    6.000000    250.000000  115.000000  3520.000000
# max     46.600000    8.000000    455.000000  230.000000  4997.000000
#
#        acceleration        year      origin
# count    317.000000  317.000000  317.000000
# mean      15.704101   77.123028    1.599369
# std        2.719913    3.127158    0.819308
# min        8.500000   70.000000    1.000000
# 25%       14.000000   75.000000    1.000000
# 50%       15.500000   77.000000    1.000000
# ...

# %%
# E)

sns.pairplot(df_auto)
plt.show()

# %% [markdown]
# E)
#
# Displacement and horsepower have a strong linear relationship, as does displacement and weight and horsepower and weight. Horsepower and mpg have a negative correlation.
#
# F)
#
# MPG looks to have a relationship with cylinders, displacement, horsepower, weight, and year. It has a weaker relationship with acceleration

# %% [markdown]
# ## Question 10
#
# This question uses the `Boston` dataset.
#
# 1.
#   1. How many rows and columns are in this dataset? What do they represent?
#   2. Make some pairwise scatterplots of the predictors in the dataset. Describe your findings
#   3. Are any of the predictors associated with per capita crime rate? If so, explain the relationship
#   4. Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor
#   5. How many of the suburbs in this data set bound the Charles River?
#   6. What is the median pupil-teacher ratio among the towns in this data set?
#   7. Which suburb of Boston has lowest median value of owner-occupied homes? What are the values of the other predictors ofr that suburb, and how do those values compare to the overall ranges for those predictors?
#   8. In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms? Comment on the suburbs that average more than eight rooms per dwelling

# %%
df_boston = pd.read_csv('data/boston.csv')
df_boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df_boston.shape
# Out:
# (506, 14)

# %% [markdown]
# A)
#
# This data set has 506 rows and 14 columns.
#
# * crim: per capita crime rate by town
# * zn: proportion of residential land zoned for lots over 25,000 sq ft
# * indus: proportion of non-retail business acres per town
# * chas: Charles River indicator, 1 if tract bounds river, 0 otherwise
# * nox: nitrogen oxides concentration (parts per 10 million)
# * rm: average number of rooms per dwelling
# * age: proportion of owner-occupied units built prior to 1940
# * dis: weighted mean of distances to five Boston employment centers
# * rad: index of accessibility to radial highways
# * tax: full property-tax rate per 10,000 dollars
# * ptratio: pupil-teacher ratio
# * black: $1000(Bk - 0.63)^2$ where $Bk$ is the proportion of black people by town
# * lstat: lower status of the population (percent)
# * medv: median value of owner-occupied homes in 1000s

# %%
sns.pairplot(df_boston)
plt.show()

# %%
# We can also look at correlation scores, which use the Pearson standard correlation coefficient
df_boston.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# B)
#
# There is a strong positive relationship between `indus` and `nox` and `indus` and `tax`. There is a strong negative relationsihp between `indus` and `dis`.
#
# There is also a strong positive relationship between `nox` and `age` and a strong negative relationship between `nox` and `dis`.
#
# There is a strong negative relationship between `age` and `dis`.
#
# There is a strong negative relationship between `lstat` and `medv`.
#
# C)
#
# No predictor is strongly correlated with crime, the highest are `rad` and `tax`. Perhaps `rad` is related to increased population density, which is attributed to crime.

# %%
df_boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       black  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
# A dataframe of towns that have the maximum value of each index
df_boston.loc[df_boston.idxmax().unique()]
# Out:
#          crim     zn  indus  chas    nox     rm    age      dis  rad  tax  \
# 380  88.97620    0.0  18.10     0  0.671  6.968   91.9   1.4165   24  666
# 57    0.01432  100.0   1.32     0  0.411  6.816   40.5   8.3248    5  256
# 488   0.15086    0.0  27.74     0  0.609  5.454   92.7   1.8209    4  711
# 142   3.32105    0.0  19.58     1  0.871  5.403  100.0   1.3216    5  403
# 364   3.47428    0.0  18.10     1  0.718  8.780   82.9   1.9047   24  666
# 8     0.21124   12.5   7.87     0  0.524  5.631  100.0   6.0821    5  311
# 353   0.01709   90.0   2.02     0  0.410  6.728   36.1  12.1265    5  187
# 356   8.98296    0.0  18.10     1  0.770  6.212   97.4   2.1222   24  666
# 354   0.04301   80.0   1.91     0  0.413  5.663   21.9  10.5857    4  334
# 0     0.00632   18.0   2.31     0  0.538  6.575   65.2   4.0900    1  296
# 374  18.49820    0.0  18.10     0  0.668  4.138  100.0   1.1370   24  666
# 161   1.46336    0.0  19.58     0  0.605  7.489   90.8   1.9709    5  403
#
# ...

# %%
fig, axes = plt.subplots(1, 3, figsize=(10,3))
axes[0].hist(df_boston['crim'])
axes[0].set_title('Histogram of Crime Rates')

axes[1].hist(df_boston['tax'])
axes[1].set_title('Histogram of Tax Rates')

axes[2].hist(df_boston['ptratio'])
axes[2].set_title('Histogram of Pupil-Teacher Ratio')

plt.show()

# %% [markdown]
# D)
#
# The majority of data for crime rates is distributed around 0, but there is a long tail with a few suburbs having high values.
#
# A significant number of suburbs are in the highest tax rate, with a gap between around 500 and 650.
#
# For pupil-teacher ratio, the data is skewed to the right, but there aren't any particularly high values

# %%
df_boston['chas'].sum()
# Out:
# 35

# %% [markdown]
# E) 35 suburbs

# %%
df_boston['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# F) 19.05 is the median

# %%
df_boston.iloc[df_boston['medv'].idxmin()]
# Out:
# crim        38.3518
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6930
# rm           5.4530
# age        100.0000
# dis          1.4896
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# black      396.9000
# lstat       30.5900
# medv         5.0000
# Name: 398, dtype: float64

# %% [markdown]
# G) Suburb 398 has the lowest median value of owner-occupied homes.
#
# Its crime rate is very high and in the top quartile. It's also in the top quartile for proportion of non-retail business acres (`indus`). It is not on the Charles River, and it's also in the top quartile for nitrogen oxides concentration (`nox`). All of the homes are also very old, as 100% were built prior to 1940 (`age`). It's in the bottom quartile for distance to  Boston employment centers, and it's in the top quartile for accessibility to highways. Taxes are also in the highest quartile, as well as the pupil-teacher ratio. It also has the highest proportion of black people amongst the suburbgs and is in the top quartile for lower status of the population.

# %%
len(df_boston.loc[df_boston['rm'] > 7])
# Out:
# 64

# %%
len(df_boston.loc[df_boston['rm'] > 8])
# Out:
# 13

# %%
# We can compare the medians of suburbs with more than 8 rooms vs 8 or less rooms
pd.DataFrame({
    "More than 8 Rooms": df_boston[df_boston['rm'] > 8].describe().loc['50%'],
    "8 Rooms or Less": df_boston[df_boston['rm'] <= 8].describe().loc['50%']
})
# Out:
#          8 Rooms or Less  More than 8 Rooms
# crim             0.24522            0.52014
# zn               0.00000            0.00000
# indus            9.69000            6.20000
# chas             0.00000            0.00000
# nox              0.53800            0.50700
# rm               6.18500            8.29700
# age             77.30000           78.30000
# dis              3.21570            2.89440
# rad              5.00000            7.00000
# tax            334.00000          307.00000
# ptratio         19.10000           17.40000
# black          391.83000          386.86000
# lstat           11.65000            4.14000
# medv            21.00000           48.30000

# %%
df_boston[df_boston['rm'] > 8].describe()
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio       black  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000   13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538  385.210769
# std    24.608723   1.883955   5.332532  110.971063   2.410580   10.529359
# ...

# %%
df_boston[df_boston['rm'] <= 8].describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  493.000000  493.000000  493.000000  493.000000  493.000000  493.000000
# mean     3.689855   11.304260   11.243793    0.066937    0.555103    6.230211
# std      8.700255   23.265932    6.866735    0.250167    0.116481    0.624223
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.080140    0.000000    5.190000    0.000000    0.449000    5.879000
# 50%      0.245220    0.000000    9.690000    0.000000    0.538000    6.185000
# 75%      3.774980   12.500000   18.100000    0.000000    0.624000    6.575000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    7.929000
#
#               age         dis         rad         tax     ptratio       black  \
# count  493.000000  493.000000  493.000000  493.000000  493.000000  493.000000
# mean    68.496755    3.804663    9.604462  410.430020   18.510751  355.921542
# ...

# %% [markdown]
# H)
#
# There are 64 suburbs with on average, more than 7 rooms per dwelling, and there are 13 suburbs with more than 8 rooms per dwelling on average.
#
# There is not much difference between the suburbs with 8 or less rooms vs more than 8 rooms, except that the median value is much higher for the suburbs with more than 8 rooms.
#
# The crime rate has a lower median for 8 or less rooms, but its top quartile includes much larger values than 'more than 8'. '8 or less' also is a bit more industrial
